# %%
import pandas as pd

# %% [markdown]
# # Series

# %%
data = pd.Series(['a', 'b', 'c', 'd'])
data
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
data=pd.Series(["a","b","c","d"])
data
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
print(data.values)
print(data.index)
# Out:
# ['a' 'b' 'c' 'd']
# RangeIndex(start=0, stop=4, step=1)

# %%
print(data.values)
print(data.index)
# Out:
# ['a' 'b' 'c' 'd']
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# # Functions that can be used with Series

# %%
data = pd.Series((3,6,9,8,5,4,2,6,3,5,8))
print(data.describe())
# Out:
# count    11.000000
# mean      5.363636
# std       2.292280
# min       2.000000
# 25%       3.500000
# 50%       5.000000
# 75%       7.000000
# max       9.000000
# dtype: float64

# %%
data=pd.Series([3,6,9,8,5,4,2,6,3,5,8])
print(data.describe())
# Out:
# count    11.000000
# mean      5.363636
# std       2.292280
# min       2.000000
# 25%       3.500000
# 50%       5.000000
# 75%       7.000000
# max       9.000000
# dtype: float64

# %%
data.agg(['sum', 'min', 'max', 'mean'])
# Out:
# sum     59.000000
# min      2.000000
# max      9.000000
# mean     5.363636
# dtype: float64

# %%
data.agg(["sum","min","max","mean"])
# Out:
# sum     59.000000
# min      2.000000
# max      9.000000
# mean     5.363636
# dtype: float64

# %%
data = pd.Series(['a', 'b', 'c', 'a', 'a', 'e', 'c'])
data.value_counts()
# Out:
# a    3
# c    2
# b    1
# e    1
# dtype: int64

# %%
data=pd.Series(['a', 'b', 'c', 'a', 'a', 'e', 'c'])
data.value_counts()
# Out:
# a    3
# c    2
# b    1
# e    1
# dtype: int64

# %%
data = ['peter', 'Paul', 'MARY', '15' , '  ' ]

print( pd.Series(data).str.isupper())# is it all calpital
print( pd.Series(data).str.islower())# is it lower ?
print( pd.Series(data).str.istitle())# is like like "This"
print( pd.Series(data).str.isspace())# is it all spaces ?
print( pd.Series(data).str.isdigit())# is it numbers ?
print( pd.Series(data).str.isalpha())# is it all letters ?
print( pd.Series(data).str.isalnum())# is it not got any spaces ?
print( pd.Series(data).str.isdecimal())# is it decimals ?
print( pd.Series(data).str.isnumeric()) # is it number
print( pd.Series(data).str.upper())# make it capital
print( pd.Series(data).str.capitalize())# make it like 'This'
print( pd.Series(data).str.lower())# make it lower
print( pd.Series(data).str.swapcase())# switch capital & small
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# dtype: bool
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool
# 0    PETER
# 1     PAUL
# 2     MARY
# 3       15
# 4
# dtype: object
# 0    Peter
# 1     Paul
# 2     Mary
# 3       15
# 4
# dtype: object
# 0    peter
# 1     paul
# 2     mary
# 3       15
# 4
# dtype: object
# 0    PETER
# 1     pAUL
# 2     mary
# 3       15
# 4
# dtype: object

# %% [markdown]
# # Plots using pandas

# %%
data = pd.Series((3,6,9,8,5,4,2,6,3,5,8))
data.plot();
# data.plot(kind='line')

# %%
data=pd.Series([1,2,3,4,5,6,7,8])
data.plot(kind="line")
# Out:
# <Axes: >

# %%
data = pd.Series((3,6,9,8,5,4,2,6,3,5,8))
data.plot(kind='pie');

# %% [markdown]
# CHAT GPT

# %%
import pandas as pd

# Create a Pandas Series
data = pd.Series((3, 6, 9, 8, 5, 4, 2, 6, 3, 5, 8))

# Define categories based on ranges of numerical values
bins = [0, 3, 6, 9, 12]  # Define your own bins as needed
labels = ['0-3', '4-6', '7-9', '10-12']  # Labels for the categories
categories = pd.cut(data, bins=bins, labels=labels)

# Count occurrences of each category
category_counts = categories.value_counts()

# Plot the pie chart
category_counts.plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
data = pd.Series((3,6,9,8,5,4,2,6,3,5,8))
data.plot(kind='bar');

# %%
data.plot(kind='barh');

# %%
data.plot(kind='hist');

# %%
data.plot(kind='box');

# %% [markdown]
# # Data Frame

# %%
import numpy as np

myarray = np.array([[6,9,8,5,4,2],[0,2,5,6,3,9],
                    [8,5,4,1,2,3],[6,9,8,5,4,2],
                    [0,5,3,6,9,8],[8,7,4,5,2,3]])

rownames = ['a', 'b','c','d','e','f']
colnames = ['one', 'two', 'three','four','five','six']
df = pd.DataFrame(myarray, index=rownames, columns=colnames)

df
# Out:
#    one  two  three  four  five  six
# a    6    9      8     5     4    2
# b    0    2      5     6     3    9
# c    8    5      4     1     2    3
# d    6    9      8     5     4    2
# e    0    5      3     6     9    8
# f    8    7      4     5     2    3

# %%
myarray = np.array([[6,9,8,5,4,2],[0,2,5,6,3,9],
                    [8,5,4,1,2,3],[6,9,8,5,4,2],
                    [0,5,3,6,9,8],[8,7,4,5,2,3]])
rownames=["a","b","c","d","e","f"]
columnnames=['one', 'two', 'three','four','five','six']
mydataframe=pd.DataFrame(myarray,index=rownames,columns=columnnames)
mydataframe
# Out:
#    one  two  three  four  five  six
# a    6    9      8     5     4    2
# b    0    2      5     6     3    9
# c    8    5      4     1     2    3
# d    6    9      8     5     4    2
# e    0    5      3     6     9    8
# f    8    7      4     5     2    3

# %%
df["one"]
# Out:
# a    6
# b    0
# c    8
# d    6
# e    0
# f    8
# Name: one, dtype: int64

# %%
mydataframe["one"]
# Out:
# a    6
# b    0
# c    8
# d    6
# e    0
# f    8
# Name: one, dtype: int64

# %% [markdown]
# # Indexing and Slicing

# %%
df['four']
# Out:
# a    5
# b    6
# c    1
# d    5
# e    6
# f    5
# Name: four, dtype: int64

# %%
df.values
# Out:
# array([[6, 9, 8, 5, 4, 2],
#        [0, 2, 5, 6, 3, 9],
#        [8, 5, 4, 1, 2, 3],
#        [6, 9, 8, 5, 4, 2],
#        [0, 5, 3, 6, 9, 8],
#        [8, 7, 4, 5, 2, 3]])

# %%
mydataframe.values
# Out:
# array([[6, 9, 8, 5, 4, 2],
#        [0, 2, 5, 6, 3, 9],
#        [8, 5, 4, 1, 2, 3],
#        [6, 9, 8, 5, 4, 2],
#        [0, 5, 3, 6, 9, 8],
#        [8, 7, 4, 5, 2, 3]])

# %%
df.columns
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %%
mydataframe.columns
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
mydataframe.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
df.iloc[:3, 2]
#:3 selects rows from the beginning up to (but not including) the row at index 3.
#2 selects the column at index 2.
# Out:
# a    8
# b    5
# c    4
# Name: three, dtype: int64

# %%
mydataframe.iloc[:4,3]
# Out:
# a    5
# b    6
# c    1
# d    5
# Name: four, dtype: int64

# %%
mydataframe.loc["a":"d","four"]
# Out:
# a    5
# b    6
# c    1
# d    5
# Name: four, dtype: int64

# %%
mydataframe["four"][:4]
# Out:
# a    5
# b    6
# c    1
# d    5
# Name: four, dtype: int64

# %%
df
# Out:
#    one  two  three  four  five  six
# a    6    9      8     5     4    2
# b    0    2      5     6     3    9
# c    8    5      4     1     2    3
# d    6    9      8     5     4    2
# e    0    5      3     6     9    8
# f    8    7      4     5     2    3

# %%
mydataframe
# Out:
#    one  two  three  four  five  six
# a    6    9      8     5     4    2
# b    0    2      5     6     3    9
# c    8    5      4     1     2    3
# d    6    9      8     5     4    2
# e    0    5      3     6     9    8
# f    8    7      4     5     2    3

# %%
df.loc['a':'e', 'four']
# Out:
# a    5
# b    6
# c    1
# d    5
# e    6
# Name: four, dtype: int64

# %%
df['four'][:3]
# Out:
# a    5
# b    6
# c    1
# Name: four, dtype: int64

# %% [markdown]
# # Indexing and Slicing Using Filters

# %%
df[(df["two"]>5) & (df["six"]>2)]
#The code is used to filter rows from DataFrame df where two conditions are met simultaneously:
# Out:
#    one  two  three  four  five  six
# f    8    7      4     5     2    3

# %%
df[(df['one'] < 5) & (df['two'] > 3)]
# Out:
#    one  two  three  four  five  six
# e    0    5      3     6     9    8

# %%
mydataframe[(mydataframe["two"]>5)&(mydataframe["six"]>2)]
# Out:
#    one  two  three  four  five  six
# f    8    7      4     5     2    3

# %% [markdown]
# # Functions that can be used with DataFrame

# %%
df.sort_values(['six'])
#withoutchange other rows
# Out:
#    one  two  three  four  five  six
# a    6    9      8     5     4    2
# d    6    9      8     5     4    2
# c    8    5      4     1     2    3
# f    8    7      4     5     2    3
# e    0    5      3     6     9    8
# b    0    2      5     6     3    9

# %%
mydataframe.sort_values('six')
# Out:
#    one  two  three  four  five  six
# a    6    9      8     5     4    2
# d    6    9      8     5     4    2
# c    8    5      4     1     2    3
# f    8    7      4     5     2    3
# e    0    5      3     6     9    8
# b    0    2      5     6     3    9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, a to f
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   one     6 non-null      int64
#  1   two     6 non-null      int64
#  2   three   6 non-null      int64
#  3   four    6 non-null      int64
#  4   five    6 non-null      int64
#  5   six     6 non-null      int64
# dtypes: int64(6)
# memory usage: 508.0+ bytes

# %%
mydataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, a to f
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   one     6 non-null      int64
#  1   two     6 non-null      int64
#  2   three   6 non-null      int64
#  3   four    6 non-null      int64
#  4   five    6 non-null      int64
#  5   six     6 non-null      int64
# dtypes: int64(6)
# memory usage: 508.0+ bytes

# %%
df.describe()
# Out:
#             one       two     three      four      five       six
# count  6.000000  6.000000  6.000000  6.000000  6.000000  6.000000
# mean   4.666667  6.166667  5.333333  4.666667  4.000000  4.500000
# std    3.723797  2.714160  2.160247  1.861899  2.607681  3.146427
# min    0.000000  2.000000  3.000000  1.000000  2.000000  2.000000
# 25%    1.500000  5.000000  4.000000  5.000000  2.250000  2.250000
# 50%    6.000000  6.000000  4.500000  5.000000  3.500000  3.000000
# 75%    7.500000  8.500000  7.250000  5.750000  4.000000  6.750000
# max    8.000000  9.000000  8.000000  6.000000  9.000000  9.000000

# %%
mydataframe.describe()
# Out:
#             one       two     three      four      five       six
# count  6.000000  6.000000  6.000000  6.000000  6.000000  6.000000
# mean   4.666667  6.166667  5.333333  4.666667  4.000000  4.500000
# std    3.723797  2.714160  2.160247  1.861899  2.607681  3.146427
# min    0.000000  2.000000  3.000000  1.000000  2.000000  2.000000
# 25%    1.500000  5.000000  4.000000  5.000000  2.250000  2.250000
# 50%    6.000000  6.000000  4.500000  5.000000  3.500000  3.000000
# 75%    7.500000  8.500000  7.250000  5.750000  4.000000  6.750000
# max    8.000000  9.000000  8.000000  6.000000  9.000000  9.000000

# %%
df.min()
# Out:
# one      0
# two      2
# three    3
# four     1
# five     2
# six      2
# dtype: int64

# %%
mydataframe.min()
# Out:
# one      0
# two      2
# three    3
# four     1
# five     2
# six      2
# dtype: int64

# %%
df['six'].mean()
# Out:
# 4.5

# %%
mydataframe["one"].mean()
# Out:
# 4.666666666666667

# %%
df1 = pd.DataFrame({'employee': ['Bob', 'Jake', 'Lisa', 'Sue'],
                    'group': ['Accounting', 'Engineering',
                              'Engineering', 'HR']})

df2 = pd.DataFrame({'employee': ['Lisa', 'Bob', 'Jake', 'Sue'],
                    'hire_date': [2004, 2008, 2012, 2014]})
print(df1)
print(df2)

df3 = pd.merge(df1, df2)
print('--------------------------')
print(df3)
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2008
# 2     Jake       2012
# 3      Sue       2014
# --------------------------
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014

# %%
df.drop('one', axis=1)
# Out:
#    two  three  four  five  six
# a    9      8     5     4    2
# b    2      5     6     3    9
# c    5      4     1     2    3
# d    9      8     5     4    2
# e    5      3     6     9    8
# f    7      4     5     2    3

# %%
df.drop('f', axis=0)
# Out:
#    one  two  three  four  five  six
# a    6    9      8     5     4    2
# b    0    2      5     6     3    9
# c    8    5      4     1     2    3
# d    6    9      8     5     4    2
# e    0    5      3     6     9    8

# %%
df.drop('f')
#default axis=0
# Out:
#    one  two  three  four  five  six
# a    6    9      8     5     4    2
# b    0    2      5     6     3    9
# c    8    5      4     1     2    3
# d    6    9      8     5     4    2
# e    0    5      3     6     9    8

# %%
df.rename(columns = {'one':'ONE'}, index = {'e':1})
# Out:
#    ONE  two  three  four  five  six
# a    6    9      8     5     4    2
# b    0    2      5     6     3    9
# c    8    5      4     1     2    3
# d    6    9      8     5     4    2
# 1    0    5      3     6     9    8
# f    8    7      4     5     2    3

# %%
df.rename(columns={"two":"TWO"},index={"e":1})
# Out:
#    one  TWO  three  four  five  six
# a    6    9      8     5     4    2
# b    0    2      5     6     3    9
# c    8    5      4     1     2    3
# d    6    9      8     5     4    2
# 1    0    5      3     6     9    8
# f    8    7      4     5     2    3

# %%
df.groupby('one')['two'].mean()
# Out:
# one
# 0    3.5
# 6    9.0
# 8    6.0
# Name: two, dtype: float64

# %%
mydataframe.groupby("one")["two"].mean()
#unique of one and the mean of two row
# Out:
# one
# 0    3.5
# 6    9.0
# 8    6.0
# Name: two, dtype: float64

# %% [markdown]
# # Operations

# %%
df
# Out:
#    one  two  three  four  five  six
# a    6    9      8     5     4    2
# b    0    2      5     6     3    9
# c    8    5      4     1     2    3
# d    6    9      8     5     4    2
# e    0    5      3     6     9    8
# f    8    7      4     5     2    3

# %%
df['one'] + df['five']
# Out:
# a    10
# b     3
# c    10
# d    10
# e     9
# f    10
# dtype: int64

# %%
df['seven'] = df['one'] + df['five']
df
# Out:
#    one  two  three  four  five  six  seven
# a    6    9      8     5     4    2     10
# b    0    2      5     6     3    9      3
# c    8    5      4     1     2    3     10
# d    6    9      8     5     4    2     10
# e    0    5      3     6     9    8      9
# f    8    7      4     5     2    3     10

# %%
# What if I want to add a new row?

# %%
df.loc["g",["one","two","three","four","five","six","seven"]]=[8	,7	,4	,5	,2	,3	,10]
df
# Out:
#    one  two  three  four  five  six  seven
# a  6.0  9.0    8.0   5.0   4.0  2.0   10.0
# b  0.0  2.0    5.0   6.0   3.0  9.0    3.0
# c  8.0  5.0    4.0   1.0   2.0  3.0   10.0
# d  6.0  9.0    8.0   5.0   4.0  2.0   10.0
# e  0.0  5.0    3.0   6.0   9.0  8.0    9.0
# f  8.0  7.0    4.0   5.0   2.0  3.0   10.0
# g  8.0  7.0    4.0   5.0   2.0  3.0   10.0
