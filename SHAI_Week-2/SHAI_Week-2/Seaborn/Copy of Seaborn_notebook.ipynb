# %% [markdown]
# # Seaborn
#
#
# #### Seaborn is a graphic library built on top of Matplotlib.
#
# most of your work in data visualization will combine between these two libraries.

# %% [markdown]
# # To get started:
# ### 1- Installation **(if you are working on colab, skip these two cells)**:
# To intall seaborn, in the anaconda prompt use the following command:
# ###### conda install seaborn
#
# if you are not using anaconda, you can install seaborn through the python prompt with the following command:
# ###### pip install seaborn
#
# To check that seaborn has been installed successfuly, check Anaconda Navigator, Environment section.
#
# Or you can type the following lines in your notebook:

# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.13.1

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Now, Let's work with real data !
#
# ### We first need to import pandas to be able to work with datasets.

# %%
import pandas as pd

# %%
iris = sns.load_dataset('iris')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # ========================
# # 1- pairplot:
#
# #### pair plot can give you a quick idea for all attributes before you start exploring each pair independently.
#
# sns.pairplot( yourData )
#
# https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
sns.pairplot(data=iris)
plt.show()

# %% [markdown]
# ### To declare the category of each point, you can use the 'hue' argument then pass the categorical variable.

# %%
sns.scatterplot(data=iris,x=iris.index,y=iris["sepal_width"],hue="species")
# Out:
# <Axes: xlabel='None', ylabel='sepal_width'>

# %%
sns.scatterplot(data=iris, x=iris.sepal_length, y=iris['sepal_length'], hue="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_length'>

# %%
sns.pairplot(data=iris,hue="species")
plt.show()

# %% [markdown]
# ### simple challenge
# Redo the previous cell but change the markers shape. read the documentation.

# %%
sns.pairplot(data=iris,hue="species",markers=["o", "s", "D"])
plt.show()

# %% [markdown]
# # =========================
#
# # 2- jointplot
#
# #### good to discover relations between different attributes
#
# sns.jointplot(data= , y= , x= )
#
# http://seaborn.pydata.org/generated/seaborn.jointplot.html

# %%
sns.jointplot(data= iris, y='sepal_width' , x='sepal_length', hue='species')
plt.show()

# %% [markdown]
# ### simple challenge
#
# Redo the previous cell but change the color palette of the species. You can try from the following map or reading this color guide:
#
# https://medium.com/@morganjonesartist/color-guide-to-seaborn-palettes-da849406d44f

# %%
sns.jointplot(data= iris, y='sepal_width' , x='sepal_length', hue='species',palette="nipy_spectral_r")
plt.show()

# %% [markdown]
# # =========================
#
# # 3- histplot (Histogram)
#
# #### good to show the number of occurrence of data in the given attribute
#
# sns.histplot(data= , x= )
#
# https://seaborn.pydata.org/generated/seaborn.histplot.html

# %%
sns.histplot(data= iris, x='sepal_length')
plt.show()

# %% [markdown]
# ### You can also separate the categories from each other using the 'hue' and/or 'multiple' arguments.
#  - hue takes a feature from your dataset.
#  - multiple takes one of the following:
#   - 'layer' (default)
#   - 'dodge'
#   - 'stack'
#   - 'fill'

# %%
sns.histplot(data= iris, x='sepal_length', hue='species')
plt.show()

# %% [markdown]
# ## simple challenge
#
# Redo the previous cell:
#  - try the 'dodge' & 'stack' choices in the argument 'multiple' and see the results.
#  - change the 'binwidth' to different values and see the results.

# %%
sns.histplot(data= iris, x='sepal_length', hue='species',multiple='stack')
plt.show()

# %%
sns.histplot(data= iris, x='sepal_length', hue='species',multiple='dodge')
plt.show()

# %% [markdown]
# # =========================
#
# # 4- Heatmap
#
# good to show how different features are related to each other.
#
# #### usually used to show correlations
#
# sns.heatmap()
#
# https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %%
iris.corr()
# Out:
# <ipython-input-14-156dd03bc859>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(), annot=True, cmap='RdBu_r')
plt.show()
# Out:
# <ipython-input-41-470fbf42c42a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris.corr(), annot=True, cmap='RdBu_r')

# %% [markdown]
# # =====================================
# # **Quartiles & Interquartiles:**
#  - https://youtu.be/9jYqZS142mg
#
#  - https://www.khanacademy.org/math/statistics-probability/summarizing-quantitative-data/interquartile-range-iqr/a/interquartile-range-review
#
# ---
#
#
#
# ## **1.Quartiles:**
# - four Values that divide your data into quarters (4 equal parts), denoted as Q1, Q2, Q3, Q4. Such that:
#  - Q1: __25%__ of the data is less than __Q1.__
#  - Q2: __50%__ of the data is less than __Q2.__ __It is also known the medien.__
#  - Q3: __75%__ of the data is less than __Q3.__
#  - Q4: __All__ the data is less than __Q4.__ __Hence, It is also known as the Maximum.__
#
# ## **2.Interquartile range (IQR):**
# - The difference between the 3rd and 1st quartiles __( IQR = Q3 - Q1 )__.
# - Why do we need IQR?
#  - Used to build box plots.
#  - It is one way to find outliers.
#
# ### َQuick example: Find Q1, Q2, Q3, Q4 and the IQR for the following data:
#
# ## -15, -9, 2, 3, 3, 4, 4, 6, 7, 7, 7, 8, 9, 11, 12, 24, 30, 40

# %% [markdown]
#  - Q1 = 3
#  - Q2 = 7
#  - Q3 = 11
#  - Q4 = 40
#  - IQR = 8

# %% [markdown]
# # Outliers:
#  - https://youtu.be/9jYqZS142mg?t=125
#  - __Definition:__ An outlier is an extremely high or low data value compared with the other data values in the dataset.
#  - In a sense, this definition leaves it up to the analyst to decide what will be considered abnormal.
#
#  - Outliers affect the statistics values of your dataset (like mean and standard deviation)
#  - **Statistically**, Outliers can be found using the following formula:
#   - **Outlier=**
#     - **Any value smaller than Q1 - 1.5 * IQR.**
#     - **Any value bigger than Q3 + 1.5 * IQR.**
#
# ### find any value that can be an outlier in the following data:
# ## -15, -9, 2, 3, 3, 4, 4, 6, 7, 7, 7, 8, 9, 11, 12, 24, 30, 40

# %% [markdown]
#  - Outliers=

# %% [markdown]
# # Boxplot:
#  - A box plot shows the five number summary of a dataset:
#    - __Minimum value.__
#    - __Lower quartile (Q1).__
#    - __Median (Q2).__
#    - __Upper quartile (Q3).__
#    - __Maximum value.__

# %% [markdown]
# ### You can draw a box plot for a feature in your dataset using the seaborn function 'boxplot'.
# #### sns.boxplot(x= )
# https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
sns.boxplot(data=iris, orient="h", palette="Set2")
plt.show()
